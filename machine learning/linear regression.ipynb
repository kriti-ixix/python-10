# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading the Data

# %%
df = pd.read_csv("Ecommerce Customers.csv")

# %%
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
sns.set_style('darkgrid')

# %%
sns.jointplot(x='Avg. Session Length', y='Yearly Amount Spent', data=df)

# %%
sns.pairplot(df)

# %% [markdown]
# ## Preparing the Data

# %%
X = df[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']]
y = df['Yearly Amount Spent']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 412            33.863189    11.523523        35.938045              3.013033
# 79             33.167137    11.928842        36.914633              3.164944
# 110            31.853075    12.149375        37.325334              3.361815
# 75             32.049839    12.238057        38.730862              3.120569
# 40             32.070546    11.733106        37.534291              4.671275
# ..                   ...          ...              ...                   ...
# 39             32.567230    12.489013        36.371480              4.222436
# 402            33.598913    13.252737        37.305961              2.935577
# 332            33.144234    11.737041        37.935189              2.190132
# 63             32.789773    11.670066        37.408748              3.414688
# 458            35.371876    10.572467        36.862183              4.198349
#
# [350 rows x 4 columns]

# %%
X_test
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 374            31.447446    10.101632        38.043453              4.238296
# 64             32.772610    13.276313        36.600777              3.462299
# 234            34.197060    13.033566        37.076795              2.633420
# 137            34.558295    11.281445        36.494406              2.491672
# 485            33.369381    12.222484        36.355235              3.447018
# ..                   ...          ...              ...                   ...
# 435            32.259973    14.132893        37.023479              3.762070
# 7              32.739143    12.351959        37.373359              4.434273
# 456            32.767076    11.076259        34.779751              2.574948
# 177            34.713451    11.724002        36.813858              4.087837
# 478            33.069768    11.764326        36.875026              3.516051
#
# [150 rows x 4 columns]

# %%
y_train
# Out:
# 412    444.053827
# 79     475.759068
# 110    459.285123
# 75     478.719357
# 40     532.751788
#           ...
# 39     537.846195
# 402    528.419330
# 332    424.202827
# 63     483.159721
# 458    537.915753
# Name: Yearly Amount Spent, Length: 350, dtype: float64

# %% [markdown]
# ## Training the Algorithm

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [500 rows x 4 columns]

# %%
lr.coef_
# Out:
# array([ 2.56149640e+01,  3.90739416e+01, -5.80834234e-02,  6.13293569e+01])

# %% [markdown]
# ## Testing the Algorithm

# %%
predictions = lr.predict(X_test)
predictions
# Out:
# array([424.75202023, 535.23570385, 511.37560189, 443.50682662,
#        508.42180104, 466.2650433 , 504.3597818 , 538.80283506,
#        491.54779126, 512.85021887, 424.06369568, 550.06858134,
#        456.28239643, 488.75488614, 486.49764898, 425.51669553,
#        589.59618209, 546.06113112, 339.13923759, 471.85393096,
#        389.8066491 , 503.79097788, 337.09178348, 497.49692082,
#        313.74349681, 416.41070527, 575.92084072, 400.62844619,
#        452.17488453, 570.35535384, 662.22763212, 450.9592621 ,
#        564.83213624, 585.97900937, 601.24814181, 499.73877656,
#        633.66738423, 579.66798191, 433.04051959, 457.06103418,
#        496.33998147, 504.46423996, 511.71865955, 642.21023489,
#        513.98167689, 552.78624907, 409.11327286, 512.39880484,
#        430.16165916, 588.70075018, 583.15052175, 616.34650774,
#        415.98157621, 431.1940759 , 580.57352234, 566.54338296,
#        561.55343805, 477.68797203, 535.75307246, 478.3241661 ,
#        553.15804604, 477.44556519, 492.58982035, 386.86704818,
#        512.99445168, 495.18020818, 607.17430737, 522.89058041,
#        634.3542728 , 381.67220566, 448.2129226 , 531.99042462,
#        503.34937921, 558.69502116, 557.23415713, 438.97287767,
#        504.98696872, 563.14720242, 619.15541618, 418.3961215 ,
#        449.24913118, 575.83198617, 553.55187927, 496.37818865,
#        598.25126232, 379.8934607 , 683.62116854, 477.2218665 ,
#        619.6456972 , 500.18253057, 556.79959122, 468.57627827,
#        489.67489345, 569.93339361, 502.06549553, 567.68220008,
#        511.35299677, 456.71595616, 544.16784743, 639.24946085,
#        576.74346464, 548.39767359, 531.95625426, 504.77807216,
#        497.55044785, 573.1584275 , 371.21189622, 283.60285679,
#        459.59958113, 475.62802061, 542.50223162, 494.41986916,
#        432.88585582, 533.87512591, 384.08800184, 440.74055823,
#        525.60625047, 564.05699254, 505.72621318, 529.88238138,
#        507.05023567, 279.33647014, 372.06311833, 559.37058391,
#        510.41045149, 478.51433409, 490.97174826, 484.81775828,
#        395.29279371, 341.40085668, 752.73802736, 456.6901966 ,
#        377.28705126, 551.99379128, 461.11011678, 445.68564482,
#        511.85626467, 517.37497771, 451.40832003, 498.92669489,
#        505.6515207 , 603.87127971, 599.05184277, 432.3054207 ,
#        569.19425022, 573.93475576, 557.82599466, 394.81432951,
#        562.64687625, 487.04876784])

# %%
y_test
# Out:
# 374    418.602742
# 64     540.263400
# 234    493.180216
# 137    433.048769
# 485    515.502480
#           ...
# 435    571.216005
# 7      549.904146
# 456    388.940549
# 177    554.900783
# 478    487.646232
# Name: Yearly Amount Spent, Length: 150, dtype: float64

# %% [markdown]
# ## Evaluate the Algorithm

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions)
# Out:
# 8.013477119637452

# %%
metrics.mean_squared_error(y_test, predictions)
# Out:
# 98.10870333097805

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions))
# Out:
# 9.904983762277354

# %%
X
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [500 rows x 4 columns]

# %%
lr.predict([[40, 20.5, 50, 7]])
# Out:
# array([1218.8096276])
